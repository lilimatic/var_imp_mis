# %%
import pandas as pd
import numpy as np
from function import *
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import PathPatch
# Out:
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
n = 10000

eps = 0 # np.random.normal(0, 0.1, n)

a = 2
b = 2

b0=0.5
b1 = 0.5

sim = 10000

p = 0.7

# %%
#df   = pd.DataFrame(np.random.uniform(0,1,size=(n, 3)),columns=['X1','X2','X3'])
#df.to_csv('data_sim.csv')  
df = pd.read_csv('data_sim.csv')
df.drop(df.columns[0],axis=1,inplace=True)

# %%
def sobol_ipw(df,n1,request,sim,a,b,eps):
    sobol_list = []
    df1 = df.copy()
    for x in range(sim):
        df_pf   = dataset(n1,df).picked(request,a,b)
        df1['Y']    =dataset(n1,df1).ishigami(eps)(a,b)/p
        df_pf['Y'] = dataset(n1,df_pf).ishigami(eps)(a,b)/p
        sobol_list.append((np.cov(df1.Y,df_pf.Y)/np.var(df1.Y))[0][1])
    return sobol_list

# %%
def higher_sobols_ipw(df,n1,sim,a,b,eps):
    singleton = []
    for x in [['X3'],['X1'],['X2'],[]]:
        singleton.append(sobol_ipw(df,n1,x,sim,a,b,eps))
    return pd.DataFrame(dict(zip(['X1_X2','X2_X3','X1_X3'],singleton)))

# %%
def higher_sobol_ipw(df,Xi,n,p,sample):
    omega = pd.DataFrame(np.random.binomial(size=n, n=1, p= p),columns=[Xi])
    omega[df.drop([Xi],axis=1).columns]=  np.ones((n,2),dtype=int)
    cc = df.where(omega==1,np.nan).dropna()
    print(len(cc))
    higher_sobol_cc = higher_sobols_ipw(cc,len(cc),sim,a,b,eps)
    #fig, ax = plt.subplots()
    #ax.boxplot(single_sobol_cc)
    #ax.set_xticklabels(single_sobol_cc.columns)
    higher_sobol_cc['sample'] = sample
    return higher_sobol_cc

# %%
higher_sobol_ipw(df,'X3',n,1,'complete')
# Out:
# 10000
#          X1_X2     X2_X3     X1_X3    sample
# 0     0.803674  0.652423  0.501665  complete
# 1     0.796554  0.656879  0.494551  complete
# 2     0.801410  0.651695  0.484301  complete
# 3     0.798373  0.669410  0.508904  complete
# 4     0.800585  0.665577  0.480919  complete
# ...        ...       ...       ...       ...
# 9995  0.800453  0.655463  0.488741  complete
# 9996  0.797005  0.660275  0.505102  complete
# 9997  0.798860  0.660016  0.494569  complete
# 9998  0.806129  0.660023  0.497220  complete
# 9999  0.796121  0.659381  0.492997  complete
#
# [10000 rows x 4 columns]

# %%
for x in ['X1','X2','X3']: #0.4,0.7,
    for p in [0.4,0.7,0.9]:
        print(x+ ' is missing')
        print()
        print(p)
        single_sobol = higher_sobol_ipw(df,x,n,1,'complete')
        single_sobol_cc = higher_sobol_ipw(df,x,n,p,'cc')

    
  
        cdf = pd.concat([single_sobol, single_sobol_cc],axis=0)  
    
        dd = pd.melt(cdf, id_vars= ['sample'],value_vars=['X1_X2','X2_X3','X1_X3'],var_name='Variable')
        dd = dd.rename(columns={'value':'First Order Effect'})
        
        dd.to_csv(f'simulation/mcar_run/mcar_mix/{x}_mcar_{p}_ipw.csv')
 
        fig, ax = plt.subplots(1, 1,figsize=(10, 5))
    
        ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
        ax.legend_.remove()
        #ax.set(ylim=(0, 0.6))
        fig = ax.get_figure()
        adjust_box_widths(fig, 0.9)
        fig.savefig('simulation/mcar/mcar_mix/MCAR_'+str(x)+'_'+str(p)+'_ipw.pdf',transparent=True,bbox_inches='tight')
# Out:
# X1 is missing
#
# 0.4
# 10000
# 3877
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X1 is missing
#
# 0.7
# 10000
# 6968
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X1 is missing
#
# 0.9
# 10000
# 9010
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X2 is missing
#
# 0.4
# 10000
# 3903
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X2 is missing
#
# 0.7
# 10000
# 6991
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X2 is missing
#
# 0.9
# 10000
# 8965
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X3 is missing
#
# 0.4
# 10000
# 4056
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X3 is missing
#
# 0.7
# 10000
# 6980
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X3 is missing
#
# 0.9
# 10000
# 9007
# <ipython-input-8-f90a46a1ecc8>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'

# %%
dX14 = pd.read_csv(f'simulation/mcar_run/mcar_mix/{x}_mcar_0.4_ipw.csv')

# %%
for x in ['X1','X2','X3']:
    dX14 = pd.read_csv(f'simulation/mcar_run/mcar_mix/{x}_mcar_0.4_ipw.csv')
    dX14['prob'] =  dX14['sample'].apply(lambda x: 1 if x =='complete' else 0.4)

    dX16 = pd.read_csv(f'simulation/mcar_run//mcar_mix/{x}_mcar_0.7_ipw.csv')
    dX16 = dX16.loc[(dX16['sample']=='cc')]
    dX16['prob'] = 0.7
    print(len(dX16))

    dX19 = pd.read_csv(f'simulation/mcar_run/mcar_mix/{x}_mcar_0.9_ipw.csv')
    dX19 = dX19.loc[(dX19['sample']=='cc')]
    dX19['prob'] = 0.9
    print(len(dX19))

    dp = pd.concat([dX14,dX16,dX19],axis=0,ignore_index=False)
    
    fig, ax = plt.subplots(1, 1,figsize=(12, 8))
    
    ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues_r'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
    ax.legend_.remove()
    ax.set(ylim=(0.45, 0.83))
    fig = ax.get_figure()
    adjust_box_widths(fig, 0.9)
    plt.xticks(fontsize = 15) 
    plt.yticks(fontsize = 15) 
    ax.set_xlabel('Variable', fontsize = 20) 
    ax.set_ylabel('First Order Effect', fontsize = 20) 
    fig.savefig(f'simulation/mcar/mcar_mix/{x}_MCAR_p_ipw_mix.pdf',transparent=True,bbox_inches='tight')
# Out:
# 30000
# 30000
# <ipython-input-16-2ecaded26365>:19: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues_r'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
# 30000
# 30000
# <ipython-input-16-2ecaded26365>:19: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues_r'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
# 30000
# 30000
# <ipython-input-16-2ecaded26365>:19: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues_r'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'

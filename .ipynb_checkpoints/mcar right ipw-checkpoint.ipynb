# %%
import pandas as pd
import numpy as np
from function import *
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import PathPatch
# Out:
# /Users/lilimatic/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
n = 10000

eps = 0 # np.random.normal(0, 0.1, n)

a = 2
b = 2

b0=0.5
b1 = 0.5

sim = 10000

p = 0.7

# %%
#df   = pd.DataFrame(np.random.uniform(0,1,size=(n, 3)),columns=['X1','X2','X3'])
#df.to_csv('data_sim.csv')  
df = pd.read_csv('data_sim.csv')
df.drop(df.columns[0],axis=1,inplace=True)

# %%
df = df[:n]

# %%
def sobol_ipw(df,n1,request,sim,a,b,eps,p):
    sobol_list = []
    df1 = df.copy()
    for x in range(sim):
        df_pf   = dataset(n1,df).picked(request,a,b)
        df1['Y']    =dataset(n1,df1).ishigami(eps)(a,b)/p
        df_pf['Y'] = dataset(n1,df_pf).ishigami(eps)(a,b)/p
        sobol_list.append((np.cov(df1.Y,df_pf.Y)/np.var(df1.Y))[0][1])
    return sobol_list

def singletons_ipw(df,n1,sim,a,b,eps,p):
    singleton = []
    for x in [['X2','X3'],['X1','X3'],['X1','X2']]:
        singleton.append(sobol_ipw(df,n1,x,sim,a,b,eps,p))
    return pd.DataFrame(dict(zip(['X1','X2','X3'],singleton)))

# %%
def singleton_ipw(df,Xi,n,p,sample):
    omega = pd.DataFrame(np.random.binomial(size=n, n=1, p= p),columns=[Xi])
    omega[df.drop([Xi],axis=1).columns]=  np.ones((n,2),dtype=int)
    cc = df.where(omega==1,np.nan).dropna()
    print(len(cc))
    single_sobol_cc = singletons_ipw(cc,len(cc),sim,a,b,eps,p)
    #fig, ax = plt.subplots()
    #ax.boxplot(single_sobol_cc)
    #ax.set_xticklabels(single_sobol_cc.columns)
    single_sobol_cc['sample'] = sample
    return single_sobol_cc

# %%
for x in ['X1','X2','X3']: #0.4,0.7,
    for p in [0.4,0.7,0.9]:
        print(x+ ' is missing')
        print()
        print(p)
        single_sobol = singleton_ipw(df,x,n,1,'complete')
        single_sobol_cc = singleton_ipw(df,x,n,p,'cc')

    
  
        cdf = pd.concat([single_sobol, single_sobol_cc],axis=0)  
    
        dd = pd.melt(cdf, id_vars= ['sample'],value_vars=['X1','X2','X3'],var_name='Variable')
        dd = dd.rename(columns={'value':'First Order Effect'})
        
        dd.to_csv(f'simulation/mcar_run/{x}_mcar_{p}_ipw.csv')
 
        fig, ax = plt.subplots(1, 1,figsize=(10, 5))
    
        ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
        ax.legend_.remove()
        ax.set(ylim=(0, 0.6))
        fig = ax.get_figure()
        adjust_box_widths(fig, 0.9)
        fig.savefig(f'simulation/mcar/MCAR_{x}_{p}_ipw.pdf',transparent=True,bbox_inches='tight')
# Out:
# X1 is missing
#
# 0.4
# 10000
# 4038
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X1 is missing
#
# 0.7
# 10000
# 7061
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X1 is missing
#
# 0.9
# 10000
# 8971
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X2 is missing
#
# 0.4
# 10000
# 3929
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X2 is missing
#
# 0.7
# 10000
# 6964
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X2 is missing
#
# 0.9
# 10000
# 8996
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X3 is missing
#
# 0.4
# 10000
# 3969
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X3 is missing
#
# 0.7
# 10000
# 7044
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'
# X3 is missing
#
# 0.9
# 10000
# 9019
# <ipython-input-7-77429d1c19d7>:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dd,hue='sample',palette=sns.color_palette('Blues'),showfliers = False) #"Blues" "cubehelix" flare_r'

# %%
for x in ['X1','X2','X3']:
    dX14 = pd.read_csv(f'simulation/mcar_run/{x}_mcar_0.4_ipw.csv')
    dX14['prob'] =  dX14['sample'].apply(lambda x: 1 if x =='complete' else 0.4)

    dX16 = pd.read_csv(f'simulation/mcar_run/{x}_mcar_0.7_ipw.csv')
    dX16 = dX16.loc[(dX16['sample']=='cc')]
    dX16['prob'] = 0.7

    dX19 = pd.read_csv(f'simulation/mcar_run/{x}_mcar_0.9_ipw.csv')
    dX19 = dX19.loc[(dX19['sample']=='cc')]
    dX19['prob'] = 0.9

    dp = pd.concat([dX14,dX16,dX19],axis=0,ignore_index=False)
    
    fig, ax = plt.subplots(1, 1,figsize=(12, 8))
    
    ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
    ax.legend_.remove()
    #ax.set(ylim=(0.05, 0.58))
    fig = ax.get_figure()
    adjust_box_widths(fig, 0.9)
    plt.xticks(fontsize = 15) 
    plt.yticks(fontsize = 15) 
    ax.set_xlabel('Variable', fontsize = 20) 
    ax.set_ylabel('First Order Effect', fontsize = 20) 
    fig.savefig(f'simulation/mcar/{x}_MCAR_p_ipw.pdf',transparent=True,bbox_inches='tight')
# Out:
# <ipython-input-8-194f5513bb57>:17: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
# <ipython-input-8-194f5513bb57>:17: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
# <ipython-input-8-194f5513bb57>:17: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   ax = sns.boxplot(x='Variable',y='First Order Effect',data=dp,hue='prob',palette=sns.color_palette('Blues'),showfliers = False,hue_order=[1,0.9,0.7,0.4]) #"Blues" "cubehelix" flare_r'
